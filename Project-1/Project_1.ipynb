# %% [markdown]
# <center> <img src = https://raw.githubusercontent.com/AndreyRysistov/DatasetsForPandas/main/hh%20label.jpg alt="drawing" style="width:400px;">

# %% [markdown]
# # <center> Проект: Анализ вакансий на hh.ru

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %% [markdown]
# # Исследование структуры данных

# %% [markdown]
# 1. Прочитайте данные с помощью библиотеки Pandas. Совет: перед чтением обратите внимание на разделитель внутри файла.

# %%
#ваш код здесь
hh_data = pd.read_csv('data\dst-3.0_16_1_hh_database.csv', sep=';')

# %% [markdown]
# 2. Выведите несколько первых (последних) строк таблицы, чтобы убедиться в том, что ваши данные не повреждены. Ознакомьтесь с признаками и их структурой.

# %%
#ваш код здесь
hh_data.head()
# Out:
#                                    Пол, возраст           ЗП  \
# 0    Мужчина ,  39 лет , родился 27 ноября 1979   29000 руб.
# 1     Мужчина ,  60 лет , родился 20 марта 1959   40000 руб.
# 2  Женщина ,  36 лет , родилась 12 августа 1982   20000 руб.
# 3      Мужчина ,  38 лет , родился 25 июня 1980  100000 руб.
# 4     Женщина ,  26 лет , родилась 3 марта 1993  140000 руб.
#
#                            Ищет работу на должность:  \
# 0                            Системный администратор
# 1                               Технический писатель
# 2                                           Оператор
# 3  Веб-разработчик (HTML / CSS / JS / PHP / базы ...
# 4                  Региональный менеджер по продажам
#
#                         Город, переезд, командировки  \
# 0  Советск (Калининградская область) , не готов к...
# 1  Королев , не готов к переезду , готов к редким...
# 2  Тверь , не готова к переезду , не готова к ком...
# 3  Саратов , не готов к переезду , готов к редким...
# ...

# %% [markdown]
# 3. Выведите основную информацию о числе непустых значений в столбцах и их типах в таблице.

# %% [markdown]
# 4. Обратите внимание на информацию о числе непустых значений.

# %%
#ваш код здесь
hh_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44744 entries, 0 to 44743
# Data columns (total 12 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Пол, возраст                     44744 non-null  object
#  1   ЗП                               44744 non-null  object
#  2   Ищет работу на должность:        44744 non-null  object
#  3   Город, переезд, командировки     44744 non-null  object
#  4   Занятость                        44744 non-null  object
#  5   График                           44744 non-null  object
#  6   Опыт работы                      44576 non-null  object
#  7   Последнее/нынешнее место работы  44743 non-null  object
#  8   Последняя/нынешняя должность     44742 non-null  object
#  9   Образование и ВУЗ                44744 non-null  object
#  10  Обновление резюме                44744 non-null  object
#  11  Авто                             44744 non-null  object
# ...

# %% [markdown]
# 5. Выведите основную статистическую информацию о столбцах.

# %%
#ваш код здесь
print(hh_data.shape)
print(hh_data['Опыт работы'].nunique())
print(hh_data['Ищет работу на должность:'].value_counts())
# Out:
# (44744, 12)
# 44413
# Системный администратор                                                  3099
# Инженер                                                                   966
# Аналитик                                                                  809
# Менеджер проектов                                                         745
# Руководитель проекта                                                      718
#                                                                          ...
# Системный администратор Linux, DevOps, Разработчик Golang                   1
# Инженер КИПиА,инженер АСУТП ,видеоинженер                                   1
# SEO-специалист | Специалист по интернет-рекламе | Интернет-маркетолог       1
# Специалист технических систем безопастности                                 1
# Аналитик данных, Математик                                                  1
# Name: Ищет работу на должность:, Length: 14929, dtype: int64

# %% [markdown]
# # Преобразование данных

# %% [markdown]
# 1. Начнем с простого - с признака **"Образование и ВУЗ"**. Его текущий формат это: **<Уровень образования год выпуска ВУЗ специальность...>**. Например:
# * Высшее образование 2016 Московский авиационный институт (национальный исследовательский университет)...
# * Неоконченное высшее образование 2000  Балтийская государственная академия рыбопромыслового флота…
# Нас будет интересовать только уровень образования.
#
# Создайте с помощью функции-преобразования новый признак **"Образование"**, который должен иметь 4 категории: "высшее", "неоконченное высшее", "среднее специальное" и "среднее".
#
# Выполните преобразование, ответьте на контрольные вопросы и удалите признак "Образование и ВУЗ".
#
# Совет: обратите внимание на структуру текста в столбце **"Образование и ВУЗ"**. Гарантируется, что текущий уровень образования соискателя всегда находится в первых 2ух слов и начинается с заглавной буквы. Воспользуйтесь этим.
#
# *Совет: проверяйте полученные категории, например, с помощью метода unique()*

# %%
#ваш код здесь
# каждую ячейку в столбце 'Образование и ВУЗ' превращаем в список с разделителем ' образование',
# берем первый элемент списка (приводим его к нижнему регистру) и записываем в новый столбец 'Образование'
hh_data['Образование'] = hh_data['Образование и ВУЗ'].apply(lambda x: x.split(' образование')[0].lower())
#Проверяем какие категории у нас получились
print('список уникальных категорий в столбце "Образование" ', hh_data['Образование'].unique())
# удаляем столбец "Образование и ВУЗ" 
hh_data.drop('Образование и ВУЗ', inplace=True, axis=1)
#3.1 Сколько соискателей имеет средний уровень образования (школьное образование)?
mean_count = hh_data['Образование'].value_counts()['среднее']
print(f'{mean_count} соискателей имеет средний уровень образования')
# Out:
# список уникальных категорий в столбце "Образование"  ['неоконченное высшее' 'высшее' 'среднее специальное' 'среднее']
# 559 соискателей имеет средний уровень образования

# %% [markdown]
# 2. Теперь нас интересует столбец **"Пол, возраст"**. Сейчас он представлен в формате **<Пол , возраст , дата рождения >**. Например:
# * Мужчина , 39 лет , родился 27 ноября 1979
# * Женщина , 21 год , родилась 13 января 2000
# Как вы понимаете, нам необходимо выделить каждый параметр в отдельный столбец.
#
# Создайте два новых признака **"Пол"** и **"Возраст"**. При этом важно учесть:
# * Признак пола должен иметь 2 уникальных строковых значения: 'М' - мужчина, 'Ж' - женщина.
# * Признак возраста должен быть представлен целыми числами.
#
# Выполните преобразование, ответьте на контрольные вопросы и удалите признак **"Пол, возраст"** из таблицы.
#
# *Совет: обратите внимание на структуру текста в столбце, в части на то, как разделены параметры пола, возраста и даты рождения между собой - символом ' , '.
# Гарантируется, что структура одинакова для всех строк в таблице. Вы можете воспользоваться этим.*

# %%
#ваш код здесь
# каждую ячейку в столбце 'Пол, возраст' превращаем в список с разделителем ' , ',
# первый элемент списка записываем в новый столбец 'Пол' 
hh_data['Пол'] = hh_data['Пол, возраст'].apply(lambda x: 'М' if x.split(' , ')[0]=='Мужчина' else 'Ж')
# второй элемент списка записываем в новый столбец 'Возраст'
hh_data['Возраст'] = hh_data['Пол, возраст'].apply(lambda x: x.split(' , ')[1])
# Преобразуем колонку 'Возраст' в целые числа
hh_data['Возраст'] = hh_data['Возраст'].apply(lambda x: int(x.split(' ')[1]))
#Удалим колонку "Пол, возраст"
hh_data.drop('Пол, возраст', inplace=True, axis=1)

# 3.2 Сколько процентов женских резюме представлено в наших данных? Ответ округлите до сотых
print(round(hh_data['Пол'].value_counts(normalize=True)['Ж'] * 100,2), '% процентов женских резюме представлено')
# Чему равен средний возраст соискателей? Ответ округлите до десятых.
print(round(hh_data['Возраст'].mean(),1), 'года составляет средний возраст соискателей')
# Out:
# 19.07 % процентов женских резюме представлено
# 32.2 года составляет средний возраст соискателей

# %% [markdown]
# 3. Следующим этапом преобразуем признак **"Опыт работы"**. Его текущий формат - это: **<Опыт работы: n лет m месяцев, периоды работы в различных компаниях…>**.
#
# Из столбца нам необходимо выделить общий опыт работы соискателя в месяцах, новый признак назовем "Опыт работы (месяц)"
#
# Для начала обсудим условия решения задачи:
# * Во-первых, в данном признаке есть пропуски. Условимся, что если мы встречаем пропуск, оставляем его как есть (функция-преобразование возвращает NaN)
# * Во-вторых, в данном признаке есть скрытые пропуски. Для некоторых соискателей в столбце стоит значения "Не указано". Их тоже обозначим как NaN (функция-преобразование возвращает NaN)
# * В-третьих, нас не интересует информация, которая описывается после указания опыта работы (периоды работы в различных компаниях)
# * В-четвертых, у нас есть проблема: опыт работы может быть представлен только в годах или только месяцах. Например, можно встретить следующие варианты:
#     * Опыт работы 3 года 2 месяца…
#     * Опыт работы 4 года…
#     * Опыт работы 11 месяцев…
#     * Учитывайте эту особенность в вашем коде
#
# Учитывайте эту особенность в вашем коде
#
# В результате преобразования у вас должен получиться столбец, содержащий информацию о том, сколько месяцев проработал соискатель.
# Выполните преобразование, ответьте на контрольные вопросы и удалите столбец **"Опыт работы"** из таблицы.

# %%
#ваш код здесь
def get_experience(str_exp):
    mounth_exp = ''
    lst_mounth = ['месяц', 'месяцев', 'месяца']
    lst_year = ['год', 'лет', 'года']
    lst_exp = str(str_exp).split(' ')
    
    if lst_exp[0] != 'Опыт':
        return np.nan
    
    if lst_exp[5] in lst_mounth:
        return int(lst_exp[2]) * 12 + int(lst_exp[4])
         
    if lst_exp[3] in lst_mounth:        
        return int(lst_exp[2])
    
    if lst_exp[3] in lst_year:
        return int(lst_exp[2]) * 12

hh_data['Опыт работы (месяц)'] = hh_data['Опыт работы'].apply(get_experience)
# Удаляем колонку "Опыт работы"
hh_data.drop('Опыт работы', inplace=True, axis=1)

# 3.3 Чему равен медианный опыт работы (в месяцах) в нашей таблице?
hh_data['Опыт работы (месяц)'].median()
# Out:
# 100.0

# %% [markdown]
# 4. Хорошо идем! Следующий на очереди признак "Город, переезд, командировки". Информация в нем представлена в следующем виде: **<Город , (метро) , готовность к переезду (города для переезда) , готовность к командировкам>**. В скобках указаны необязательные параметры строки. Например, можно встретить следующие варианты:
#
# * Москва , не готов к переезду , готов к командировкам
# * Москва , м. Беломорская , не готов к переезду, не готов к командировкам
# * Воронеж , готов к переезду (Сочи, Москва, Санкт-Петербург) , готов к командировкам
#
# Создадим отдельные признаки **"Город"**, **"Готовность к переезду"**, **"Готовность к командировкам"**. При этом важно учесть:
#
# * Признак **"Город"** должен содержать только 4 категории: "Москва", "Санкт-Петербург" и "город-миллионник" (их список ниже), остальные обозначьте как "другие".
#
#     Список городов-миллионников:
#
#    <code>million_cities = ['Новосибирск', 'Екатеринбург','Нижний Новгород','Казань', 'Челябинск','Омск', 'Самара', 'Ростов-на-Дону', 'Уфа', 'Красноярск', 'Пермь', 'Воронеж','Волгоград']
#     </code>
#     Инфорация о метро, рядом с которым проживает соискатель нас не интересует.
# * Признак **"Готовность к переезду"** должен иметь два возможных варианта: True или False. Обратите внимание, что возможны несколько вариантов описания готовности к переезду в признаке "Город, переезд, командировки". Например:
#     * … , готов к переезду , …
#     * … , не готова к переезду , …
#     * … , готова к переезду (Москва, Санкт-Петербург, Ростов-на-Дону)
#     * … , хочу переехать (США) , …
#
#     Нас интересует только сам факт возможности или желания переезда.
# * Признак **"Готовность к командировкам"** должен иметь два возможных варианта: True или False. Обратите внимание, что возможны несколько вариантов описания готовности к командировкам в признаке "Город, переезд, командировки". Например:
#     * … , готов к командировкам , …
#     * … , готова к редким командировкам , …
#     * … , не готов к командировкам , …
#
#     Нас интересует только сам факт готовности к командировке.
#
#     Еще один важный факт: при выгрузки данных у некоторых соискателей "потерялась" информация о готовности к командировкам. Давайте по умолчанию будем считать, что такие соискатели не готовы к командировкам.
#
# Выполните преобразования и удалите столбец **"Город, переезд, командировки"** из таблицы.
#
# *Совет: обратите внимание на то, что структура текста может меняться в зависимости от указания ближайшего метро. Учите это, если будете использовать порядок слов в своей программе.*

# %%
#ваш код здесь
def get_city(arg):
    million_cities = ['Москва', 'Санкт-Петербург', 'Новосибирск', 'Екатеринбург', 'Нижний Новгород', 
                      'Казань', 'Челябинск', 'Омск', 'Самара', 'Ростов-на-Дону',
                      'Уфа', 'Красноярск', 'Пермь', 'Воронеж', 'Волгоград' ]
    lst_arg = arg.split(' ,')
    if lst_arg[0] in million_cities:
        return lst_arg[0]
    else:
        return 'другие'
        
def get_move(arg):   
    lst_arg = arg.split(',') 
    if len(lst_arg) == 3:
        if 'не готов' in lst_arg[1]:
            return False
        else:
            return True
    else:
        if 'не готов' in lst_arg[2]:
            return False
        else:
            return True  
        
def get_trip(arg):
    lst_arg = arg.split(',') 
    # проверяем есть ли слово "готов" в последнем элементе (все пустые или некорректные записи проставим False)
    if 'готов' in lst_arg[-1]:
        if ' не готов' in lst_arg[-1]:
            return False
        else:
            return True
    else:
        return False
     
hh_data['Город'] = hh_data['Город, переезд, командировки'].apply(get_city)
hh_data['Готовность к переезду'] = hh_data['Город, переезд, командировки'].apply(get_move)
hh_data['Готовность к командировкам'] = hh_data['Город, переезд, командировки'].apply(get_trip)
#Удалим колонку "Город, переезд, командировки"
hh_data.drop('Город, переезд, командировки', inplace=True, axis=1)

# 3.4 Сколько процентов соискателей живут в Санкт-Петербурге? Ответ округлите до целого
percent = round(hh_data['Город'].value_counts(normalize=True)['Санкт-Петербург'] * 100)
print(f'в Санкт-Петербурге живёт {percent}% соискателей ')

#Сколько процентов соискателей готовы одновременно и к переездам, и к командировкам? Ответ округлите до целого.
mask = (hh_data['Готовность к переезду']==True) & (hh_data['Готовность к командировкам']==True)
percent = round(hh_data[mask].shape[0]/hh_data.shape[0] * 100)
print(f'Одновременно и к переездам, и к командировкам готовы {percent}% соискателей')
# Out:
# в Санкт-Петербурге живёт 11% соискателей
# Одновременно и к переездам, и к командировкам готовы 32% соискателей

# %% [markdown]
# 5. Рассмотрим поближе признаки **"Занятость"** и **"График"**. Сейчас признаки представляют собой набор категорий желаемой занятости (полная занятость, частичная занятость, проектная работа, волонтерство, стажировка) и желаемого графика работы (полный день, сменный график, гибкий график, удаленная работа, вахтовый метод).
# На сайте hh.ru соискатель может указывать различные комбинации данных категорий, например:
# * полная занятость, частичная занятость
# * частичная занятость, проектная работа, волонтерство
# * полный день, удаленная работа
# * вахтовый метод, гибкий график, удаленная работа, полная занятость
#
# Такой вариант признаков имеет множество различных комбинаций, а значит множество уникальных значений, что мешает анализу. Нужно это исправить!
#
# Давайте создадим признаки-мигалки для каждой категории: если категория присутствует в списке желаемых соискателем, то в столбце на месте строки рассматриваемого соискателя ставится True, иначе - False.
#
# Такой метод преобразования категориальных признаков называется One Hot Encoding и его схема представлена на рисунке ниже:
# <img src=https://raw.githubusercontent.com/AndreyRysistov/DatasetsForPandas/main/ohe.jpg>
# Выполните данное преобразование для признаков "Занятость" и "График", ответьте на контрольные вопросы, после чего удалите их из таблицы

# %%
#ваш код здесь
#Распарсим столбец "Занятость"
hh_data['полная занятость'] = hh_data['Занятость'].apply(lambda x: True if 'полная занятость' in x else False)
hh_data['частичная занятость'] = hh_data['Занятость'].apply(lambda x: True if 'частичная занятость' in x else False)
hh_data['проектная работа'] = hh_data['Занятость'].apply(lambda x: True if 'проектная работа' in x else False)
hh_data['волонтерство'] = hh_data['Занятость'].apply(lambda x: True if 'волонтерство' in x else False)
hh_data['стажировка'] = hh_data['Занятость'].apply(lambda x: True if 'стажировка' in x else False)
# Распарсим столбец "График"
hh_data['полный день'] = hh_data['График'].apply(lambda x: True if 'полный деньь' in x else False)
hh_data['сменный график'] = hh_data['График'].apply(lambda x: True if 'сменный график' in x else False)
hh_data['гибкий график'] = hh_data['График'].apply(lambda x: True if 'гибкий график' in x else False)
hh_data['удалённая работа'] = hh_data['График'].apply(lambda x: True if 'удалённая работа' in x else False)
hh_data['вахтовый метод'] = hh_data['График'].apply(lambda x: True if 'вахтовый метод' in x else False)

#3.5 Сколько людей ищут проектную работу и волонтёрство (в обоих столбцах стоит True)?
mask = (hh_data['проектная работа']==True) & (hh_data['волонтерство']==True)
count = hh_data[mask].shape[0]
print(f'{count} ищут проектную работу и волонтёрство')
#Сколько людей хотят работать вахтовым методом и с гибким графиком (в обоих столбцах стоит True)
mask = (hh_data['вахтовый метод']==True) & (hh_data['гибкий график']==True)
count = hh_data[mask].shape[0]
print(f'{count} хотят работать вахтовым методом и с гибким графиком')

#Удаляем столбцы "Занятость" и "График"
hh_data.drop('Занятость', inplace=True, axis=1)
hh_data.drop('График', inplace=True, axis=1)
# Out:
# 436 ищут проектную работу и волонтёрство
# 2311 хотят работать вахтовым методом и с гибким графиком

# %% [markdown]
# 6. (2 балла) Наконец, мы добрались до самого главного и самого важного - признака заработной платы **"ЗП"**.
# В чем наша беда? В том, что помимо желаемой заработной платы соискатель указывает валюту, в которой он бы хотел ее получать, например:
# * 30000 руб.
# * 50000 грн.
# * 550 USD
#
# Нам бы хотелось видеть заработную плату в единой валюте, например, в рублях. Возникает вопрос, а где взять курс валют по отношению к рублю?
#
# На самом деле язык Python имеет в арсенале огромное количество возможностей получения данной информации, от обращения к API Центробанка, до использования специальных библиотек, например pycbrf. Однако, это не тема нашего проекта.
#
# Поэтому мы пойдем в лоб: обратимся к специальным интернет-ресурсам для получения данных о курсе в виде текстовых файлов. Например, MDF.RU, данный ресурс позволяет удобно экспортировать данные о курсах различных валют и акций за указанные периоды в виде csv файлов. Мы уже сделали выгрузку курсов валют, которые встречаются в наших данных за период с 29.12.2017 по 05.12.2019. Скачать ее вы можете **на платформе**
#
# Создайте новый DataFrame из полученного файла. В полученной таблице нас будут интересовать столбцы:
# * "currency" - наименование валюты в ISO кодировке,
# * "date" - дата,
# * "proportion" - пропорция,
# * "close" - цена закрытия (последний зафиксированный курс валюты на указанный день).
#
#
# Перед вами таблица соответствия наименований иностранных валют в наших данных и их общепринятых сокращений, которые представлены в нашем файле с курсами валют. Пропорция - это число, за сколько единиц валюты указан курс в таблице с курсами. Например, для казахстанского тенге курс на 20.08.2019 составляет 17.197 руб. за 100 тенге, тогда итоговый курс равен - 17.197 / 100 = 0.17197 руб за 1 тенге.
# Воспользуйтесь этой информацией в ваших преобразованиях.
#
# <img src=https://raw.githubusercontent.com/AndreyRysistov/DatasetsForPandas/main/table.jpg>
#
#
# Осталось только понять, откуда брать дату, по которой определяется курс? А вот же она - в признаке **"Обновление резюме"**, в нем содержится дата и время, когда соискатель выложил текущий вариант своего резюме. Нас интересует только дата, по ней бы и будем сопоставлять курсы валют.
#
# Теперь у нас есть вся необходимая информация для того, чтобы создать признак "ЗП (руб)" - заработная плата в рублях.
#
# После ответа на контрольные вопросы удалите исходный столбец заработной платы "ЗП" и все промежуточные столбцы, если вы их создавали.

# %% [markdown]
# Итак, давайте обсудим возможный алгоритм преобразования:
# 1. Перевести признак "Обновление резюме" из таблицы с резюме в формат datetime и достать из него дату. В тот же формат привести признак "date" из таблицы с валютами.
# 2. Выделить из столбца "ЗП" сумму желаемой заработной платы и наименование валюты, в которой она исчисляется. Наименование валюты перевести в стандарт ISO согласно с таблицей выше.
# 3. Присоединить к таблице с резюме таблицу с курсами по столбцам с датой и названием валюты (подумайте, какой тип объединения надо выбрать, чтобы в таблице с резюме сохранились данные о заработной плате, изначально представленной в рублях). Значение close для рубля заполнить единицей 1 (курс рубля самого к себе)
# 4. Умножить сумму желаемой заработной платы на присоединенный курс валюты (close) и разделить на пропорцию (обратите внимание на пропуски после объединения в этих столбцах), результат занести в новый столбец "ЗП (руб)".

# %%
#ваш код здесь
def get_currency(arg):
    currency_dict = {'грн': 'UAH', 'USD': 'USD', 'EUR': 'EUR',
                     'белруб': 'BYN', 'KGS': 'KGS', 'сум': 'UZS',
                     'AZN': 'AZN', 'KZT': 'KZT', 'руб': 'RUB'}
    item = arg.split()[1].replace('.','')
    return currency_dict[item]

hh_data['ЗП (число)'] = hh_data['ЗП'].apply(lambda x: float(x.split()[0]))
hh_data['currency'] = hh_data['ЗП'].apply(get_currency)
hh_data['Обновление резюме'] = pd.to_datetime(hh_data['Обновление резюме']).dt.date 
# Прочитаем файл с курсами валют на дату
exchange_rates = pd.read_csv('data\ExchangeRates.csv')
exchange_rates['date'] = pd.to_datetime(exchange_rates['date']).dt.date 

new_hh = hh_data.merge(exchange_rates,
                       left_on=['currency', 'Обновление резюме'],
                       right_on=['currency','date'],
                       how='left')
new_hh['close'] = new_hh['close'].fillna(1)
new_hh['proportion'] = new_hh['proportion'].fillna(1)
# Добавим новую колонку "ЗП (руб)"
hh_data['ЗП (руб)'] = new_hh['ЗП (число)'] * new_hh['close'] / new_hh['proportion']
# Удалим созданные ранее столбцы
hh_data.drop(['ЗП', 'currency', 'ЗП (число)'], inplace=True, axis=1)

#3.6 Чему равна желаемая медианная заработная плата соискателей в нашей таблице (в рублях)?
print(round(hh_data['ЗП (руб)'].median()/1000))
# Out:
# 59

# %% [markdown]
# # Исследование зависимостей в данных

# %% [markdown]
# 1. Постройте распределение признака **"Возраст"**. Опишите распределение, отвечая на следующие вопросы: чему равна мода распределения, каковы предельные значения признака, в каком примерном интервале находится возраст большинства соискателей? Есть ли аномалии для признака возраста, какие значения вы бы причислили к их числу?
# *Совет: постройте гистограмму и коробчатую диаграмму рядом.*

# %%
# ваш код здесь
# Построим коробчатую диаграмму
fig = px.box(hh_data,
             x='Возраст',
             title='Распределение признака "Возраст"',
             width=1000
             )
# fig.show('notebook')
# fig.write_html("plotly/box_4_1.html")
# Построим гистаграмму
fig = px.histogram(data_frame=hh_data,
                   x=['Возраст'], 
                   title='Распределение признака "Возраст"',
                   width=1000
                   )

# fig.show('notebook')
# fig.write_html("plotly/hist_4_1.html")
#4.1 Чему равно модальное значение возраста соискателей?
moda = hh_data['Возраст'].mode()[0]
print(f'Модальное значение возраста соискателей равно {moda} лет')
# Out:
# Модальное значение возраста соискателей равно 30 лет

# %% [markdown]
# <img src=https://raw.githubusercontent.com/CorhariS/sf_data_science/main/Project-1/plotly/box_4_1.png>
# <img src=https://raw.githubusercontent.com/CorhariS/sf_data_science/main/Project-1/plotly/hist_4_1.png>

# %% [markdown]
# Модальное значение возраста соискателей равно 30 лет. Данные распределены от 14 до 100 лет (min и max). Из коробчатой диаграммы видно, что медиана равна 31 год,  большинство соискателей находятся в интевале от 27 до 36 лет. Так же существуют выбросы справа. Анализ гистаграммы показывает, что есть аномалии для признака "Возраст". Это по одному соискателю, которым 76, 77 и 100 лет.

# %% [markdown]
# 2. Постройте распределение признака **"Опыт работы (месяц)"**. Опишите данное распределение, отвечая на следующие вопросы: чему равна мода распределения, каковы предельные значения признака, в каком примерном интервале находится опыт работы большинства соискателей? Есть ли аномалии для признака опыта работы, какие значения вы бы причислили к их числу?
# *Совет: постройте гистограмму и коробчатую диаграмму рядом.*

# %%
# Построим коробчатую диаграмму
fig = px.box(hh_data,
             x='Опыт работы (месяц)',
             title='Распределение признака "Опыт работы (месяц)"',
             width=1000
             )
# fig.show('notebook')
# fig.write_html("plotly/box_4_2.html")

# Построим гистаграмму
fig = px.histogram(data_frame=hh_data,
                   x=['Опыт работы (месяц)'], 
                   title='Распределение признака "Опыт работы (месяц)"',
                   width=1000,
                   labels={'value': 'Опыт работы в месяцах'}
                   )
# fig.show('notebook')
# fig.write_html("plotly/hist_4_2.html")

# Чему равно модальное значение опыта работы соискателей?
moda = hh_data['Опыт работы (месяц)'].mode()[0]
print(f'Модальное значение опыта работы соискателей равно {moda} месяцев')
# 4.2 Чему равен максимальный опыт работы (в месяцах)?
max_exp = hh_data['Опыт работы (месяц)'].max()
print(f'максимальный опыт работы составляет {max_exp} месяцев')
# Out:
# Модальное значение опыта работы соискателей равно 81.0 месяцев
# максимальный опыт работы составляет 1188.0 месяцев

# %% [markdown]
# <img src=https://raw.githubusercontent.com/CorhariS/sf_data_science/main/Project-1/plotly/box_4_2.png>
# <img src=https://raw.githubusercontent.com/CorhariS/sf_data_science/main/Project-1/plotly/hist_4_2.png>

# %% [markdown]
# Модальное значение опыта работы соискателей соискателей равно 81 месяц. Данные распределены от 0 до 1188 месяцев (min и max). Из коробчатой диаграммы видно, что медиана равна 100 месяцев,  большинство соискателей имеют опыт работы в интевале от 57 до 154 месяцев. Так же существуют выбросы справа. Анализ гистаграммы показывает, что есть аномалии для признака "Опыт работы (месяц)". Это соискатель с опытом работы в 1188 месяцев

# %% [markdown]
# 3. Постройте распределение признака **"ЗП (руб)"**. Опишите данное распределение, отвечая на следующие вопросы: каковы предельные значения признака, в каком примерном интервале находится заработная плата большинства соискателей? Есть ли аномалии для признака ЗП? Обратите внимание на гигантские размеры желаемой заработной платы.
# *Совет: постройте гистограмму и коробчатую диаграмму рядом.*

# %%
# Построим коробчатую диаграмму
fig = px.box(hh_data,
             x='ЗП (руб)',
             title='Распределение признака "ЗП (руб)"',
             width=1000
             )
# fig.show('notebook')
# fig.write_html("plotly/box_4_3.html")

# Построим гистаграмму
fig = px.histogram(data_frame=hh_data,
                   x=['ЗП (руб)'], 
                   title='Распределение признака "ЗП (руб)"',
                   width=1000,
                   labels={'value': 'ЗП (руб)'}
                   )
# fig.show('notebook')
# fig.write_html("plotly/hist_4_3.html")

# Чему равно модальное значение ЗП соискателей?
moda = hh_data['ЗП (руб)'].mode()[0]
print(f'Модальное значение заработной платы соискателей равно {moda} руб.')
# 4.3 сколько соискателей требуют заработную плату выше 1 миллиона рублей?
wage = hh_data[hh_data['ЗП (руб)']>10**6].shape[0]
print(f'{wage} соискателей требуют заработную плату выше 1 миллиона рублей')
# Out:
# Модальное значение заработной платы соискателей равно 50000.0 руб.
# 5 соискателей требуют заработную плату выше 1 миллиона рублей

# %% [markdown]
# <img src=https://raw.githubusercontent.com/CorhariS/sf_data_science/main/Project-1/plotly/box_4_3.png>
# <img src=https://raw.githubusercontent.com/CorhariS/sf_data_science/main/Project-1/plotly/hist_4_3.png>

# %% [markdown]
# Модальное значение заработной платы соискателей равно 50000.0 руб. Данные распределены от 1 до 24.3 млн. руб месяцев (min и max). Из коробчатой диаграммы видно, что медиана равна 59 019 руб.,  большинство соискателей требуют заработную плату в интевале от 37 548 до 95 000 руб. Так же существуют выбросы справа. Анализ гистаграммы показывает, что есть аномалии для признака "ЗП (руб)". Это 5 соискателей с заработной платой свыше 1 млн. руб.

# %% [markdown]
# 4. Постройте диаграмму, которая показывает зависимость **медианной** желаемой заработной платы (**"ЗП (руб)"**) от уровня образования (**"Образование"**). Используйте для диаграммы данные о резюме, где желаемая заработная плата меньше 1 млн рублей.
# *Сделайте выводы по представленной диаграмме: для каких уровней образования наблюдаются наибольшие и наименьшие уровни желаемой заработной платы? Как вы считаете, важен ли признак уровня образования при прогнозировании заработной платы?*

# %%
mask = hh_data['ЗП (руб)']<10**6
median_wage = hh_data[mask].groupby('Образование', as_index=False)['ЗП (руб)'].median()
# Построим столбчатую диаграмму
fig = px.bar(
    data_frame=median_wage,
    x='Образование',
    y='ЗП (руб)',
    color='Образование',
    text='ЗП (руб)',
    height=500,
    width=800,
    title='зависимость медианной желаемой заработной платы от уровня образования'  
)
# fig.show('notebook')
# fig.write_html("plotly/bar_4_4.html")

# Построим коробчатую диаграмму
fig = px.box(hh_data[mask],
             x='ЗП (руб)',
             y='Образование',
             title='Взаимосвязь заработной платы от образования',
             width=1000
             )
# fig.show('notebook')
# fig.write_html("plotly/box_4_4.html")

# %% [markdown]
# <img src=https://raw.githubusercontent.com/CorhariS/sf_data_science/main/Project-1/plotly/bar_4_4.png>
# <img src=https://raw.githubusercontent.com/CorhariS/sf_data_science/main/Project-1/plotly/box_4_4.png>

# %% [markdown]
# Из столбчатой диаграммы видно, что медиана категории "Высшее" (образование) составляет 60к руб. и является наибольшим значением среди медиан других категорий. Затем в порядке убывания располагаются значения медиан следующих категорий: "неоконченное высшее"(50к руб), "среднее специальное" и "среднее" (40к руб). Из коробчатой диаграммы видно, что большинство соискателей имеют образование "высшее" и требуют большую заработную плату. Я считаю, что при прогнозировании заработной платы следует учитывать признак "образование", но желательно еще в разрезе признака "Ищет работу на должность:".

# %% [markdown]
# 5. Постройте диаграмму, которая показывает распределение желаемой заработной платы (**"ЗП (руб)"**) в зависимости от города (**"Город"**). Используйте для диаграммы данные о резюме, где желая заработная плата меньше 1 млн рублей.
# *Сделайте выводы по полученной диаграмме: как соотносятся медианные уровни желаемой заработной платы и их размах в городах? Как вы считаете, важен ли признак города при прогнозировании заработной платы?*

# %%
# ваш код здесьmask = hh_data['ЗП (руб)']<10**6
median_wage = hh_data[mask].groupby('Город', as_index=False)['ЗП (руб)'].median()
# Построим столбчатую диаграмму
fig = px.bar(
    data_frame=median_wage,
    x='Город',
    y='ЗП (руб)',
    color='Город',
    text='ЗП (руб)',
    height=500,
    width=800,
    title='зависимость медианной желаемой заработной платы от города'  
)
# fig.show('notebook')
# fig.write_html("plotly/bar_4_5.html")

# Построим коробчатую диаграмму
fig = px.box(hh_data[mask],
             x='ЗП (руб)',
             y='Город',
             title='Распределение желаемой заработной платы в зависимости от города',
             width=1000
             )
# fig.show('notebook')
# fig.write_html("plotly/box_4_5.html")

# %% [markdown]
# <img src=https://raw.githubusercontent.com/CorhariS/sf_data_science/main/Project-1/plotly/bar_4_5.png>
# <img src=https://raw.githubusercontent.com/CorhariS/sf_data_science/main/Project-1/plotly/box_4_5.png>

# %% [markdown]
# Из первой диаграммы видно, что максимальная медиана желаемой заработной платы присутствует в городе Москва (85к руб), затем город Санкт-Петербург (60к руб) и город Екатеринбург (50к руб). В остальных городах медина желаемой заработной платы находится в интервале от 35к руб до 45к руб. На второй диаграмме так же показано, что большенство соискателей из города Москва в интервале заработной платы от 60к руб до 150к руб. При прогнозировании заработной платы обязательно следует учитывать призник "город".
#
# #4.5 В каком городе (категории городов) зафиксирован наибольший показатель желаемой заработной платы (~924 тысячи рублей)?
# Из второй диаграммы видно, что наибольший показатель желаемой заработной платы (~924 тысячи рублей) зафиксирован в городе "другие"

# %% [markdown]
# 6. Постройте **многоуровневую столбчатую диаграмму**, которая показывает зависимость медианной заработной платы (**"ЗП (руб)"**) от признаков **"Готовность к переезду"** и **"Готовность к командировкам"**. Проанализируйте график, сравнив уровень заработной платы в категориях.

# %%
median_wage = hh_data.groupby(['Готовность к переезду', 'Готовность к командировкам'], as_index=False)['ЗП (руб)'].median()
# Построим столбчатую диаграмму
fig = px.bar(
    data_frame=median_wage,
    x=median_wage['Готовность к переезду'].apply(lambda x: 'готов к переезду' if x==True else 'не готов к переезду'),
    y='ЗП (руб)',
    color=median_wage['Готовность к командировкам'].apply(lambda x: 'готов к командировкам' if x==True else 'не готов к командировкам'),
    text='ЗП (руб)',
    barmode='group',
    height=500,
    width=1100,
    title='зависимость медианной ЗП (руб) от признаков «Готовность к переезду» и «Готовность к командировкам»'  
)
# fig.show('notebook')
# fig.write_html("plotly/bar_4_6.html")

# %% [markdown]
# <img src=https://raw.githubusercontent.com/CorhariS/sf_data_science/main/Project-1/plotly/bar_4_6.png>

# %% [markdown]
#  Из диаграммы видно, желаемая медианная заработная плата соискателей, готовых и к переезду, и к командировкам равна 65 900 руб. (или округленная 66к руб). Так же наблюдается, что не зависимо от переезда соискатели в большенстве готовы к командировкам.

# %% [markdown]
# 7. Постройте сводную таблицу, иллюстрирующую зависимость **медианной** желаемой заработной платы от возраста (**"Возраст"**) и образования (**"Образование"**). На полученной сводной таблице постройте **тепловую карту**. Проанализируйте тепловую карту, сравнив показатели внутри групп.

# %%
pivot = hh_data.pivot_table(index='Образование', columns='Возраст', values='ЗП (руб)', aggfunc='median')

sns.set(rc = {'figure.figsize':(15,8)})
heatmap = sns.heatmap(data=pivot, cmap='YlGnBu', annot=False, cbar_kws={'label': 'медиана ЗП соискателей'})
heatmap.set_title('зависимость медианной заработной платы от возраста и образования', fontsize=16);
plt.xlabel('Возраст')
plt.ylabel('Образование')
plt.show()

# %% [markdown]
# Из диаграммы видно, что самый быстрый карьерный рост наблюдается для категории образования "высшее". Медленный рост заработной платы с увеличением признака "возраст" наблюдается для категорий образования "среднее" и "среднее специальное". Для признака "возраст" в интервале от 65 и до 100 лет необходимо дополнительное исследование на присутствие аномальных данных.

# %% [markdown]
# 8. Постройте **диаграмму рассеяния**, показывающую зависимость опыта работы (**"Опыт работы (месяц)"**) от возраста (**"Возраст"**). Опыт работы переведите из месяцев в года, чтобы признаки были в едином масштабе. Постройте на графике дополнительно прямую, проходящую через точки (0, 0) и (100, 100). Данная прямая соответствует значениям, когда опыт работы равен возрасту человека. Точки, лежащие на этой прямой и выше нее - аномалии в наших данных (опыт работы больше либо равен возрасту соискателя)

# %%
# Построим диаграмму рассеивания
fig = px.scatter(
    data_frame=hh_data,
    x='Возраст',
    y=hh_data['Опыт работы (месяц)']/12,
    width=800,
    height=500,
    title='Зависомость опыта работы от возраста',
    labels={'Возраст': 'Возраст (лет)', 'y': 'Опыт работы (лет)'}
)
# Добавим линию с координатами (0,0) и (100,100)
fig.add_shape(type='line', x0=0, y0=0, x1=100, y1=100)
# fig.show('notebook')
# fig.write_html("plotly/scatter_4_8.html")

# %% [markdown]
# <img src=https://raw.githubusercontent.com/CorhariS/sf_data_science/main/Project-1/plotly/scatter_4_8.png>

# %% [markdown]
# Из диаграммы видно, что выше линии лежат 7 точек (при увеличении на прямой находятся 3 точки). Получается у нас 7 аномальных точек, когда возраст соискателя меньше, чем опыт его работы.

# %% [markdown]
# **Дополнительные баллы**
#
# Для получения 2 дополнительных баллов по разведывательному анализу постройте еще два любых содержательных графика или диаграммы, которые помогут проиллюстрировать влияние признаков/взаимосвязь между признаками/распределения признаков. Приведите выводы по ним. Желательно, чтобы в анализе участвовали признаки, которые мы создавали ранее в разделе "Преобразование данных".

# %%
gender_df = hh_data.groupby('Пол', as_index=False)['ЗП (руб)'].mean()

fig = px.bar(gender_df,
                   x=gender_df['Пол'].apply(lambda x: 'Мужчины' if x=='М' else 'Женщины'),
                   y='ЗП (руб)',
                   color='Пол',
                   title='Зависимость средней заработной платы от гендерной принадлежности соискателя',
                   labels={'x': 'Пол соискателя'},
                   width=1000)
# fig.show('notebook')
# fig.write_html("plotly/bar_dop_1.html")

gender_df = hh_data.groupby('Пол', as_index=False)['Готовность к переезду'].value_counts(normalize=True)

fig = px.bar(gender_df,
                   x=gender_df['Пол'].apply(lambda x: 'Мужчины' if x=='М' else 'Женщины'),
                   y=gender_df.proportion * 100,
                   color='Готовность к переезду',
                   title='Процент "готовность к переезду" взависимости от гендерной принадлежности',
                   text=round(gender_df.proportion * 100,2).astype('string') + '%',
                   labels={'x': 'Пол соискателя', 'y': 'Проценты'},
                   width=1000)
# fig.show('notebook')
# fig.write_html("plotly/bar_dop_2.html")

# %% [markdown]
# <img src= https://raw.githubusercontent.com/CorhariS/sf_data_science/main/Project-1/plotly/bar_dop_1.png>
# <img src= https://raw.githubusercontent.com/CorhariS/sf_data_science/main/Project-1/plotly/bar_dop_2.png>

# %% [markdown]
# Из первой диаграммы видно, что женщины в среднем требуют меньшую заработную плату нежели мужчины. Но зато мужчины более готовы к переезду в другой город (почти 38%) по сравнению с женщинами (почти 27%)

# %% [markdown]
# # Очистка данных

# %% [markdown]
# 1. Начнем с дубликатов в наших данных. Найдите **полные дубликаты** в таблице с резюме и удалите их.

# %%
hh_data_duplicates = hh_data[hh_data.duplicated()]
print(f'Число найденных дубликатов: {hh_data_duplicates.shape[0]}')
# Удалим дубликаты
hh_data = hh_data.drop_duplicates()
# Out:
# Число найденных дубликатов: 161

# %% [markdown]
# 2. Займемся пропусками. Выведите информацию **о числе пропусков** в столбцах.

# %%
cols_null_percent = hh_data.isnull().sum()
cols_with_null = cols_null_percent[cols_null_percent>0].sort_values(ascending=False)
display(cols_with_null)
# Out:
# Опыт работы (месяц)                168
# Последняя/нынешняя должность         2
# Последнее/нынешнее место работы      1
# dtype: int64

# %% [markdown]
# 3. Итак, у нас есть пропуски в 3ех столбцах: **"Опыт работы (месяц)"**, **"Последнее/нынешнее место работы"**, **"Последняя/нынешняя должность"**. Поступим следующим образом: удалите строки, где есть пропуск в столбцах с местом работы и должностью. Пропуски в столбце с опытом работы заполните **медианным** значением.

# %%
# Удаляем строки где есть пропусти по признакам 'Последняя/нынешняя должность' и 'Последнее/нынешнее место работы'
hh_data = hh_data.dropna(how='any', subset=['Последняя/нынешняя должность','Последнее/нынешнее место работы'], axis=0)
# Заполним пропуски медианой в признаке 'Опыт работы (месяц)'
values = {'Опыт работы (месяц)': hh_data['Опыт работы (месяц)'].median()}
hh_data = hh_data.fillna(values)
mean_exp = round(hh_data['Опыт работы (месяц)'].mean())
print(f'среднее значение в столбце «Опыт работы (месяц)» равно {mean_exp} месяцев')
# Out:
# среднее значение в столбце «Опыт работы (месяц)» равно 114 месяцев

# %% [markdown]
# 4. Мы добрались до ликвидации выбросов. Сначала очистим данные вручную. Удалите резюме, в которых указана заработная плата либо выше 1 млн. рублей, либо ниже 1 тыс. рублей.

# %%
#Удаляем строки, где ЗП (руб) меньше 1 000 и больше 10**6
mask = (hh_data['ЗП (руб)'] < 1000) | (hh_data['ЗП (руб)'] > 10**6) 
print(f'{hh_data[mask].shape[0]} строк, где ЗП (руб) меньше 1 000 и больше 10 млн')
hh_data = hh_data.drop(hh_data[mask].index, axis=0)
# Out:
# 89 строк, где ЗП (руб) меньше 1 000 и больше 10 млн

# %% [markdown]
# 5. В процессе разведывательного анализа мы обнаружили резюме, в которых **опыт работы в годах превышал возраст соискателя**. Найдите такие резюме и удалите их из данных

# %%
# найдем все строки, где "Возраст" меньше "Опыта работы"
mask = hh_data['Возраст'] < (hh_data['Опыт работы (месяц)']/12)
print(f'опыт работы в годах превышает возраст у {hh_data[mask].shape[0]} соискателей')
# Удалим такие строки
hh_data = hh_data.drop(hh_data[mask].index, axis=0)
# Out:
# опыт работы в годах превышает возраст у 7 соискателей

# %% [markdown]
# 6. В результате анализа мы обнаружили потенциальные выбросы в признаке **"Возраст"**. Это оказались резюме людей чересчур преклонного возраста для поиска работы. Попробуйте построить распределение признака в **логарифмическом масштабе**. Добавьте к графику линии, отображающие **среднее и границы интервала метода трех сигм**. Напомним, сделать это можно с помощью метода axvline. Например, для построение линии среднего будет иметь вид:
#
# `histplot.axvline(log_age.mean(), color='k', lw=2)`
#
# В какую сторону асимметрично логарифмическое распределение? Напишите об этом в комментарии к графику.
# Найдите выбросы с помощью метода z-отклонения и удалите их из данных, используйте логарифмический масштаб. Давайте сделаем послабление на **1 сигму** (возьмите 4 сигмы) в **правую сторону**.
#
# Выведите таблицу с полученными выбросами и оцените, с каким возрастом соискатели попадают под категорию выбросов?

# %%
fig, ax = plt.subplots(1, 1, figsize=(8, 4))
log_year = np.log(hh_data['Возраст'] + 1)
histplot = sns.histplot(log_year, bins=30, ax=ax)
histplot.axvline(log_year.mean(), color='k', lw=2)
histplot.axvline(log_year.mean()+ 3 * log_year.std(), color='k', ls='--', lw=2)
histplot.axvline(log_year.mean()- 3 * log_year.std(), color='k', ls='--', lw=2)
histplot.set_title('Распределение признака "Возраст" в логарифмическом масштабе')

fig.show()

def outliers_z_score_mod(data, feature, log_scale=False, left=3, right=3):
    """
    Функция возращающая датафремы выбросов и очищенных записей по методу z отклонений
    """
    if log_scale:
        x = np.log(data[feature])
    else:
        x = data[feature]
    mu = x.mean()
    sigma = x.std()
    lower_bound = mu - left * sigma
    upper_bound = mu + right * sigma
    outliers = data[(x < lower_bound) | (x > upper_bound)]
    cleaned = data[(x > lower_bound) & (x < upper_bound)]
    return outliers, cleaned

# Сделаем послабление вправо на 1 сигму 
outliers_z, cleaned_z = outliers_z_score_mod(hh_data, 'Возраст', log_scale=True, left=3, right=4)
# выведем количество выбросов
print(f'{outliers_z.shape[0]} выброса после "послабления"  вправо на 1 сигму')
print(outliers_z['Возраст'].value_counts())
# Out:
# C:\Users\CorhariS\AppData\Local\Temp\2\ipykernel_6792\2506313991.py:9: UserWarning:
#
# Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
# 3 выброса после "послабления"  вправо на 1 сигму
# 15     2
# 100    1
# Name: Возраст, dtype: int64

# %% [markdown]
# из графика видно, что распределение имеет правостороннюю асимметрию. При помощи z-отклонения получено 3 выброса после "послабления"  вправо на 1 сигму. Так же попали под категорию выброса 2 соискателя с возрастом 15 лет и один соискатель с возрастом 100 лет.
